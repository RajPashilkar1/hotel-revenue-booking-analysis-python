# %% [markdown]
# <h1 align="center">Hotel Revenue & Booking Performance Analysis<h1>

# %% [markdown]
# The hospitality industry depends heavily on booking trends, occupancy rate,
# and platform performance.
#
# This project analyzes hotel booking data to:
# - Understand revenue performance
# - Identify high and low performing cities
# - Analyze booking platforms
# - Support data-driven business decisions

# %% [markdown]
# ***
# ### ==> 1. Import Libraries
# ***

# %%
# Importing libraries

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt

#configuration libraries
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***
# ### ==> 2. Data Import and Data Exploration
# ***

# %% [markdown]
# ### Datasets
# We have 5 csv file
#
#    - dim_date.csv
#    - dim_hotels.csv
#    - dim_rooms.csv
#    - fact_aggregated_bookings
#    - fact_bookings.csv

# %% [markdown]
# **Read bookings data in a datagrame**

# %%
df_bookings = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\fact_bookings.csv")

# %% [markdown]
# **Explore bookings data**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **Rest of the Data files**

# %%
df_date = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\dim_date.csv")
df_hotels = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\dim_hotels.csv")
df_rooms = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\dim_rooms.csv")
df_agg_bookings = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\fact_aggregated_bookings.csv")

# %% [markdown]
# **Explore aggregate Dates**

# %%
df_date.shape
# Out:
# (92, 4)

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date['week no'].value_counts()
# Out:
# week no
# W 19    7
# W 20    7
# W 21    7
# W 22    7
# W 23    7
# W 24    7
# W 25    7
# W 26    7
# W 27    7
# W 28    7
# W 29    7
# W 30    7
# W 31    7
# W 32    1
# Name: count, dtype: int64

# %% [markdown]
# **Explore aggregate Hotels**

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **Explore aggregate Rooms**

# %%
df_rooms.shape
# Out:
# (4, 2)

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# **Explore aggregate bookings**

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
# ***
# ### ==> 3. Data Cleaning
# ***

# %% [markdown]
#  df_bookings Data set

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. Also we should not replace this rating with a median or mean rating etc

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **(1) Clean invalid guests**

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %% [markdown]
# As you can see above, number of guests having less than zero value represents data error. We can ignore these records.

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %% [markdown]
# **(2) Outlier removal in revenue generated**

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.median()
# Out:
# (15378.036937686695, 13500.0)

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263742.4278566132

# %%
df_bookings[df_bookings.revenue_generated<=0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<=higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33479.3586618449

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %% [markdown]
# One observation we can have in above dataframe is that all rooms are RT4 which means presidential suit. Now since RT4 is a luxurious room it is likely their rent will be higher. To make a fair analysis, we need to do data analysis only on RT4 room types

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# mean + 3*standard deviation
23439+3*9048
# Out:
# 50583

# %% [markdown]
# Here higher limit comes to be 50583 and in our dataframe above we can see that max value for revenue realized is 45220. Hence we can conclude that there is no outlier and we don't need to do any data cleaning on this particular column

# %%
df_bookings[df_bookings.booking_id=="May012216559RT41"]
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 137  May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 137        4.0           RT4           others            NaN    Checked Out
#
#      revenue_generated  revenue_realized
# 137              38760             38760

# %% [markdown]
# df_agg_bookings Data set

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings['capacity'].fillna(
    df_agg_bookings['capacity'].median(),
    inplace=True
)

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %% [markdown]
# ***
# ### ==> 4. Data Transformation
# ***

# %% [markdown]
# **Create occupancy percentage column**

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis=1)

# %%
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#        occ_pct
# 0     0.833333
# ...

# %% [markdown]
# Convert it to a percentage value

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings['occ_pct'].apply(lambda x: round(x*100, 2))

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# ***
# ### ==> 5. Insights Generation
# ***

# %% [markdown]
# **1. What is an average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    58.232748
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
df.drop('room_id', axis=1, inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard
# 4    94.74   Standard

# %%
avg_occ = df.groupby("room_class")["occ_pct"].mean()
avg_occ
# Out:
# room_class
# Elite           58.040278
# Premium         58.028213
# Presidential    59.300461
# Standard        58.232748
# Name: occ_pct, dtype: float64

# %%
df[df.room_class=="Standard"].occ_pct.mean()
# Out:
# 58.23274782608696

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    x=avg_occ.index,
    y=avg_occ.values,
    palette="Set2"
)

plt.title("Average Occupancy % by Room Class")
plt.xlabel("Room Class")
plt.ylabel("Occupancy Percentage")
plt.show()

# %% [markdown]
# Presidential rooms have the highest average occupancy rate, followed by Elite and Premium rooms, while Standard rooms show slightly lower occupancy.

# %% [markdown]
# **2. Print average occupancy rate per city**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on="property_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai
# 4    94.74   Standard   Atliq Grands    Luxury      Delhi

# %%
avg_city_occ = df.groupby("city")["occ_pct"].mean()
avg_city_occ
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.943142
# Name: occ_pct, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    x=avg_city_occ.index,
    y=avg_city_occ.values,
    palette="Set1"
)

plt.title("Average Occupancy Rate per City")
plt.xlabel("City")
plt.ylabel("Average Occupancy (%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Delhi records the highest average occupancy rate, while Bangalore shows relatively lower utilization, indicating city-wise demand variation.

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df, df_date, left_on="check_in_date", right_on="date")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 4    57.89   Standard  Atliq Grands    Luxury     Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# ...

# %%
avg_day_occ = (
    df
    .groupby("day_type")["occ_pct"]
    .mean().
    round(2)
)

avg_day_occ
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(
    x=avg_day_occ.index,
    y=avg_day_occ.values,
    palette="Set2"
)

plt.title("Average Occupancy: Weekday vs Weekend")
plt.xlabel("Day Type")
plt.ylabel("Average Occupancy (%)")
plt.show()

# %% [markdown]
# Weekend occupancy is higher than weekday occupancy, indicating stronger leisure travel demand.

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities**

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
june_data = df[df["mmm yy"]=="Jun 22"]
june_data.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#       occ_pct room_class  property_name  category       city       date  \
# 2200    66.67   Standard  Atliq Exotica    Luxury     Mumbai  10-Jun-22
# 2201    63.33   Standard      Atliq Bay    Luxury  Bangalore  10-Jun-22
# 2202    56.67   Standard   Atliq Palace  Business  Bangalore  10-Jun-22
# 2203    47.37   Standard   Atliq Grands    Luxury     Mumbai  10-Jun-22
# 2204    57.89   Standard   Atliq Grands    Luxury      Delhi  10-Jun-22
#
#       mmm yy week no  day_type
# 2200  Jun 22    W 24  weekeday
# ...

# %%
june_city_occ = (
    june_data
    .groupby("city")["occ_pct"]
    .mean()
    .round(2)
    .sort_values(ascending=False)
)

june_city_occ
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    x=june_city_occ.index,
    y=june_city_occ.values,
    palette="Set1"
)

plt.title("Average Occupancy by City — June")
plt.xlabel("City")
plt.ylabel("Average Occupancy (%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# In June, Delhi leads in hotel occupancy, while Bangalore shows relatively lower utilization, indicating strong city-wise seasonal demand differences.

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data**

# %%
df_august = pd.read_csv(r"C:\Users\pashi\OneDrive\Desktop\Data_Science\project_hospitality_analysis\datasets\new_data_august.csv")
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 14)

# %%
latest_df = pd.concat([df, df_august], ignore_index = True, axis = 0)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city       date  \
# ...

# %%
latest_df.shape
# Out:
# (6507, 15)

# %% [markdown]
# **6. Print revenue realized per city**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on="property_id")
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
revenue_city = df_bookings_all.groupby("city")["revenue_realized"].sum()
revenue_city
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    x=revenue_city.index,
    y=revenue_city.values,
    palette="Set2"
)

plt.title("Revenue Realized per City")
plt.xlabel("City")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Mumbai contributes the highest share of total revenue, while Delhi generates comparatively lower revenue despite strong occupancy, highlighting the impact of pricing strategy.

# %% [markdown]
# **7. Print month by month revenue**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] = pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_bookings_all
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT15        16558     27-04-22      1/5/2022
# 2        May012216558RT16        16558     1/5/2022      1/5/2022
# 3        May012216558RT17        16558     28-04-22      1/5/2022
# 4        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22      31-07-22
# 134569   Jul312217564RT46        17564     29-07-22      31-07-22
# 134570   Jul312217564RT48        17564     30-07-22      31-07-22
# 134571   Jul312217564RT49        17564     29-07-22      31-07-22
# 134572  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings_all['check_in_date'] = pd.to_datetime(
    df_bookings_all['check_in_date'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
monthly_revenue = (
    df_bookings_all
    .groupby("mmm yy")["revenue_realized"]
    .sum()
    .reset_index()
)

monthly_revenue
# Out:
#    mmm yy  revenue_realized
# 0  Jul 22         572843348
# 1  Jun 22         553925855
# 2  May 22         581767396

# %%
month_order = ["May 22", "Jun 22", "Jul 22"]

monthly_revenue["mmm yy"] = pd.Categorical(
    monthly_revenue["mmm yy"],
    categories=month_order,
    ordered=True
)

monthly_revenue = monthly_revenue.sort_values("mmm yy")
monthly_revenue
# Out:
#    mmm yy  revenue_realized
# 2  May 22         581767396
# 1  Jun 22         553925855
# 0  Jul 22         572843348

# %%
plt.figure(figsize=(8,5))
sns.lineplot(
    data=monthly_revenue,
    x="mmm yy",
    y="revenue_realized",
    marker="o"
)

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue Realized")
plt.show()

# %% [markdown]
# Revenue peaked in May, declined in June, and rebounded in July, highlighting clear seasonal demand trends.

# %% [markdown]
# **8. Print revenue realized per hotel type**

# %%
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city  \
# ...

# %%
revenue_hotel_type = (
    df_bookings_all
    .groupby("category")["revenue_realized"]
    .sum()
    .sort_values(ascending=False)
)

revenue_hotel_type
# Out:
# category
# Luxury      1052569562
# Business     655967037
# Name: revenue_realized, dtype: int64

# %%
plt.figure(figsize=(6,6))

plt.pie(
    revenue_hotel_type.values,
    labels=revenue_hotel_type.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Revenue Share by Hotel Type")
plt.show()

# %% [markdown]
# Luxury hotels contribute over 60%+ of total revenue, highlighting the strong impact of premium offerings on overall business performance.

# %% [markdown]
# **9. Print average rating per city**

# %%
avg_rating_city = df_bookings_all.groupby('city')['ratings_given'].mean()
avg_rating_city
# Out:
# city
# Bangalore    3.407681
# Delhi        3.779298
# Hyderabad    3.661041
# Mumbai       3.650545
# Name: ratings_given, dtype: float64

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    x=avg_rating_city.index,
    y=avg_rating_city.values,
    palette="Set2"
)

plt.title("Average Customer Rating per City")
plt.xlabel("City")
plt.ylabel("Average Rating")
plt.ylim(0, 5)
plt.show()

# %% [markdown]
# Delhi records the highest customer satisfaction, while Bangalore shows relatively lower ratings, highlighting opportunities for service improvement.

# %% [markdown]
# **10. Print a pie chart of revenue realized per booking platform**

# %%
df_bookings_all
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-05-01
# 1        May012216558RT15        16558     27-04-22    2022-05-01
# 2        May012216558RT16        16558     1/5/2022    2022-05-01
# 3        May012216558RT17        16558     28-04-22    2022-05-01
# 4        May012216558RT18        16558     26-04-22    2022-05-01
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134569   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134570   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134571   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134572  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
platform_revenue = (
    df_bookings_all
    .groupby("booking_platform")["revenue_realized"]
    .sum()
    .sort_values(ascending=False)
)

platform_revenue
# Out:
# booking_platform
# others            699306762
# makeyourtrip      340814104
# logtrip           187494028
# direct online     168948637
# tripster          123066801
# journey           102531334
# direct offline     86374933
# Name: revenue_realized, dtype: int64

# %%
plt.figure(figsize=(7,7))

plt.pie(
    platform_revenue.values,
    labels=platform_revenue.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Revenue Share by Booking Platform")
plt.show()

# %% [markdown]
# A significant portion of revenue comes from OTAs, with MakeYourTrip being the leading individual platform, while direct bookings contribute a smaller share.
